# %% [markdown]
# ### 로드

# %%
# %pip install chromadb sentence_transformers gdown dotenv openai

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %%
import chromadb
from sentence_transformers import SentenceTransformer
import torch
import os
from chromadb.utils import embedding_functions


# ---------------------------------------------------------
# 1. 설정 (GPU 확인 등)
# ---------------------------------------------------------
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# ---------------------------------------------------------
# 2. 모델 로드 (저장할 때 썼던 그 모델!)
# ---------------------------------------------------------
print("모델 로드 중...")
doc_model = SentenceTransformer("dragonkue/BGE-m3-ko").to(device)

ipc_model = embedding_functions.OpenAIEmbeddingFunction(
    api_key=os.getenv("OPENAI_API_KEY"),
    model_name="text-embedding-3-small",
)

# ---------------------------------------------------------
# 3. ChromaDB 연결 (다운로드 받은 폴더 경로 지정)
# ---------------------------------------------------------
doc_client = chromadb.PersistentClient(path="./doc_db")
doc_collection = doc_client.get_collection(name="patent_claims")

ipc_client = chromadb.PersistentClient(path="./ipc_db")
ipc_collection = ipc_client.get_collection(name="ipc_clean")

print(f"✅ doc 데이터베이스 로드 완료! 총 데이터 수: {doc_collection.count()}개")
print(f"✅ ipc 데이터베이스 로드 완료! 총 데이터 수: {ipc_collection.count()}개")
# Out:
# Using device: cpu
# 모델 로드 중...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 20
#      17 print("모델 로드 중...")
#      18 doc_model = SentenceTransformer("dragonkue/BGE-m3-ko").to(device)
# ---> 20 ipc_model = embedding_functions.OpenAIEmbeddingFunction(
#      21     api_key=os.getenv("OPENAI_API_KEY"),
#      22     model_name="text-embedding-3-small",
#      23 )
#      25 # ---------------------------------------------------------
#      26 # 3. ChromaDB 연결 (다운로드 받은 폴더 경로 지정)
#      27 # ---------------------------------------------------------
#      28 doc_client = chromadb.PersistentClient(path="./doc_db")
#
# File c:\Users\Playdata\.conda\envs\3rdpro_env\Lib\site-packages\chromadb\utils\embedding_functions\openai_embedding_function.py:67, in OpenAIEmbeddingFunction.__init__(self, api_key, model_name, organization_id, api_base, api_type, api_version, deployment_id, default_headers, dimensions, api_key_env_var)
#      65 self.api_key = api_key or os.getenv(self.api_key_env_var)
#      66 if not self.api_key:
# ---> 67     raise ValueError(
#      68         f"The {self.api_key_env_var} environment variable is not set."
#      69     )
#      71 self.model_name = model_name
#      72 self.organization_id = organization_id
#
# ValueError: The CHROMA_OPENAI_API_KEY environment variable is not set.

# %% [markdown]
# ### 검색

# %%
# ---------------------------------------------------------
# 4. Doc DB 확인용 함수 (view)
# ---------------------------------------------------------
def search_doc(query_text, top_k=10):
    # 1) 검색어를 벡터로 변환 (임베딩)
    query_vector = doc_model.encode(query_text).tolist()

    # 2) 벡터로 DB 검색
    results = doc_collection.query(query_embeddings=[query_vector], n_results=top_k)

    # 3) 결과 출력
    print(f"\n🔍 검색어: '{query_text}'")

    for i in range(top_k):
        doc = results["documents"][0][i]
        meta = results["metadatas"][0][i]
        distance = results["distances"][0][i]

        print(f"--- [Rank {i+1}] (거리: {distance:.4f}) ---")
        print(f"특허명: {meta.get('title', '제목없음')}")
        print(f"특허ID: {meta.get('patent_id')} (Claim {meta.get('claim_no')})")
        print(f"내용: {doc}")


search_doc("환자의 신체 부위 내에서 내시경을 위치 파악하기 위한 방법")
# Out:
# 🔍 검색어: '환자의 신체 부위 내에서 내시경을 위치 파악하기 위한 방법'
# --- [Rank 1] (거리: 0.2531) ---
# 특허명: 내시경 위치 파악 시스템 및 방법
# 특허ID: 1020257025260 (Claim 1)
# 내용: 환자의 신체 부위 내에서 내시경을 위치 파악하기 위한 방법으로서,(a) 일련의 EM(electromagnetic) 데이터를 획득하는 단계;(b) 상기 일련의 EM 데이터에 적어도 부분적으로 기초하여 EM 데이터 기반 경로를 생성하는 단계;(c) 상기 일련의 EM 데이터의 데이터 포인트에 적어도 부분적으로 기초하여, 상기 환자의 신체 부위의 생물학적 모델에 기초한 형상을 갖는 하나 이상의 경로 가설을 식별하는 단계;(d) 최적화 알고리즘을 이용하여 상기 하나 이상의 경로 가설을 상기 EM 데이터 기반 경로에 매핑함으로써 하나 이상의 변형된 경로를 생성하는 단계; 및(e) 상기 하나 이상의 경로 가설 각각과 관련된 확률에 적어도 부분적으로 기초하여 상기 하나 이상의 변형된 경로로부터 변형된 경로를 선택하고, 그 선택된 변형된 경로에 기초하여 상기 내시경의 팁의 위치를 결정하는 단계를 포함하는, 방법.
# --- [Rank 2] (거리: 0.3384) ---
# 특허명: 내시경 위치 파악 시스템 및 방법
# 특허ID: 1020257025260 (Claim 17)
# 내용: 환자의 신체 부위 내에서 내시경을 위치 파악하기 위한 시스템으로서,컴퓨터 실행 가능 명령어를 저장하는 메모리; 및상기 내시경과 통신하고 상기 컴퓨터 실행 가능 명령어를 실행하여, (a) 일련의 EM(electromagnetic) 데이터를 획득하고; (b) 상기 일련의 EM 데이터에 적어도 부분적으로 기초하여 EM 데이터 기반 경로를 생성하며; (c) 상기 일련의 EM 데이터의 데이터 포인트에 적어도 부분적으로 기초하여, 상기 환자의 신체 부위의 생물학적 모델에 기초한 형상을 갖는 하나 이상의 경로 가설을 식별하고;  (d) 최적화 알고리즘을 이용하여 상기 하나 이상의 경로 가설을 상기 EM 데이터 기반 경로에 매핑함으로써 하나 이상의 변형된 경로를 생성하고; (e) 상기 하나 이상의 경로 가설 각각과 관련된 확률에 적어도 부분적으로 기초하여 상기 하나 이상의 변형된 경로로부터 변형된 경로를 선택하고, 그 선택된 변형된 경로에 기초하여 상기 내시경의 팁의 위치를 결정하도록구성되는 것인, 하나 이상의 프로세서를 포함하는, 시스템.
# --- [Rank 3] (거리: 0.3500) ---
# 특허명: 표적 해부학적 특징부 위치결정
# 특허ID: 1020227037609 (Claim 18)
# 내용: 해부학적 특징부를 표적설정하는 방법으로서,내시경으로서, 상기 내시경의 원위 단부 부분과 연관된 위치 센서를 포함하는, 상기 내시경을 환자의 표적 해부학적 내강 내로 전진시키는 단계;상기 위치 센서를 사용하여 상기 표적 해부학적 내강 내에서의 상기 내시경의 복수의 위치들과 연관된 위치 데이터를 기록하는 단계;상기 위치 데이터에 적어도 부분적으로 기초하여 상기 표적 해부학적 내강의 표면을 추정하는 단계; 및상기 표적 해부학적 내강의 상기 추정된 표면에 적어도 부분적으로 기초하여 상기 표적 해부학적 내강의 축을 결정하는 단계를 포함하는, 방법.
# --- [Rank 4] (거리: 0.3815) ---
# 특허명: 하이브리드 영상화 및 조종용 시스템 및 방법
# 특허ID: 1020227046133 (Claim 24)
# 내용: 상기 위치 데이터는 상기 내시경 장치의 원위 부분에 위치한 EM 센서에 의해 포착되는 것인, 방법.
# --- [Rank 5] (거리: 0.3843) ---
# 특허명: 가요성 내시경의 원격 및 자율 제어를 위한 시스템, 방법 및 디바이스
# 특허ID: 1020257019367 (Claim 17)
# 내용: 스코프 샤프트의 길이를 따라 배치된 복수의 센서를 사용하여 체강 내에서 상기 스코프 샤프트의 포지션, 위치 및 이동 중 적어도 하나를 결정하는 단계를 더 포함하는, 내시경 시술 수행 방법.
# --- [Rank 6] (거리: 0.3846) ---
# 특허명: 하이브리드 영상화 및 조종용 시스템 및 방법
# 특허ID: 1020227046133 (Claim 1)
# 내용: 환자의 해부학적 내강 네트워크를 통과해 내시경 장치를 조종(navigation)하는 방법으로서:(a) 관절형 세장형 부재의 원위 선단에게 미리 정해진 경로를 따라 이동하도록 명령하는 단계;(b) (a)와 동시에, 위치 센서 데이터 및 운동학 데이터(kinematics data)를 수집하는 단계; 및(c) 상기 위치 센서 데이터 및 상기 운동학 데이터에 기초하여 상기 원위 선단의 추정 롤 각도(roll angle)를 계산하는 단계를 포함하는 방법.
# --- [Rank 7] (거리: 0.3937) ---
# 특허명: 하이브리드 영상화 및 조종용 시스템 및 방법
# 특허ID: 1020227046133 (Claim 23)
# 내용: 환자의 해부학적 내강 네트워크를 통과해 내시경 장치를 조종하는 방법으로서:(a) 해부학적 내강 네트워크를 통과해 상기 내시경 장치를 조종하는 동안 위치 데이터를 포착하는 단계;(b) 상기 내시경 장치의 조종 운동으로부터 호흡 운동을 구별함으로써 생성되는 호흡 운동 모델을 머신 러닝 알고리즘 훈련 모델의 도움으로 상기 위치 데이터에 기초하여 생성하는 단계; 및(c) 상기 생성된 호흡 운동 모델을 이용하여 호흡 운동을 보상하여 상기 내시경 장치의 원위 단부를 조향하기 위한 명령을 생성하는 단계를 포함하는 방법.
# --- [Rank 8] (거리: 0.3991) ---
# 특허명: 수술 동안 내시경용 광원을 자동으로 켜기/끄기 위한 방법 및 시스템
# 특허ID: 1020257012063 (Claim 2)
# 내용: 상기 내시경이 상기 환자의 신체에 삽입되었는지 또는 상기 환자의 신체 외부에 있는지를 결정하기 위해 상기 실시간 비디오 이미지들을 처리하는 단계는 상기 수신된 실시간 비디오 이미지들에 기초하여, 상기 내시경을 상기 환자의 신체 외부로부터 상기 환자의 신체 내부로 이동시키는 제2 전이 이벤트를 검출하는 단계를 더 포함하고, 상기 제2 전이 이벤트가 검출될 때 상기 내시경은 상기 환자의 신체에 삽입된 것으로 결정되는, 컴퓨터-구현식 방법.
# --- [Rank 9] (거리: 0.4076) ---
# 특허명: 내시경 위치 파악 시스템 및 방법
# 특허ID: 1020257025260 (Claim 7)
# 내용: 상기 신체 부위는 폐이고, 상기 내시경은 기관지경(bronchoscope)인, 방법.
# --- [Rank 10] (거리: 0.4090) ---
# 특허명: 단층 영상 합성 및 증강 형광 투시를 이용하는 로봇 내시경 시스템을 위한 시스템 및 방법
# 특허ID: 1020257020207 (Claim 31)
# 내용: 내시경 디바이스를 위한 컴퓨터-구현 방법으로서:(a) 그래픽 사용자 인터페이스(GUI)의 항행 모드에서, 피험자 내의 표적을 향해 내시경 디바이스를 항행하는 단계로서, GUI는 내시경 디바이스의 항행을 안내하도록 시각적 요소를 갖는 가상 뷰를 표시하는 것인 단계;(b) GUI의 단층 영상 합성 모드로의 전환시, ⅰ) 내시경 디바이스의 일부분 및 표적을 포함하는 일련의 형광 투시 이미지 프레임으로서, 일련의 형광 투시 이미지 프레임을 취득하는 이미징 시스템의 다양한 자세에 대응하는 것인 일련의 형광 투시 이미지 프레임을 수신하고, ⅱ) 이미징 시스템의 자세에 적어도 부분적으로 기초하여 재구성된 3D 단층 영상 합성 이미지를 생성하며, ⅲ) 재구성된 3D 단층 영상 합성 이미지에 적어도 부분적으로 기초하여 표적의 위치를 결정하는 단계; 및(c) GUI의 형광 투시 뷰 모드로의 전환시, ⅰ) 형광 투시 뷰 모드에서 취득된 형광 투시 이미지 프레임과 관련된 이미징 시스템의 자세를 취득하고, ⅱ) 단계 (b)에서 결정된 표적의 위치 및 상기 이미징 시스템의 자세에 적어도 부분적으로 기초하여 형광 투시 이미지 프레임 상에 표시되는 표적의 오버레이를 생성하는 단계를 포함하는 컴퓨터-구현 방법.

# %%
# ---------------------------------------------------------
# 5. Doc DB 확인용 함수 (view)
# ---------------------------------------------------------
def search_ipc(query_text, top_k=10):
    # 1) 검색어를 벡터로 변환 (임베딩)
    query_vector = ipc_model(query_text)[0].tolist()

    # 2) 벡터로 DB 검색
    results = ipc_collection.query(query_embeddings=[query_vector], n_results=top_k)

    # 3) 결과 출력
    print(f"\n🔍 검색어: '{query_text}'")

    for i in range(top_k):
        ipc_explain = results["documents"][0][i]
        meta = results["metadatas"][0][i]
        ids = results["ids"][0][i]
        distance = results["distances"][0][i]

        print(f"--- [Rank {i+1}] (거리: {distance:.4f}) ---")
        print(f"코드: {ids} (Path {meta.get('path')})")
        print(f"분류: {meta.get('kind')}")
        print(f"내용: {ipc_explain}")


search_ipc(
    "ARTIFICIAL INTELLIGENCE COMPUTER VISION-BASED ALZHEIMER'S DIAGNOSIS SYSTEM AND METHOD USING SUBJECT'S PUPIL MOVEMENT AND MICROSACCADE"
)
# Out:
# 🔍 검색어: 'ARTIFICIAL INTELLIGENCE COMPUTER VISION-BASED ALZHEIMER'S DIAGNOSIS SYSTEM AND METHOD USING SUBJECT'S PUPIL MOVEMENT AND MICROSACCADE'
# --- [Rank 1] (거리: 1.0780) ---
# 코드: A61B3/08 (Path A > A61 > A61B > A61B3/00 > A61B3/02 > A61B3/08)
# 분류: 2
# 내용: HUMAN NECESSITIES MEDICAL OR VETERINARY SCIENCE HYGIENE DIAGNOSIS SURGERY IDENTIFICATION Apparatus for testing the eyes Instruments for examining the eyes Subjective types, i.e. testing apparatus requiring the active assistance of the patient for testing binocular or stereoscopic vision, e.g. strabismus
# --- [Rank 2] (거리: 1.0793) ---
# 코드: G06V40/60 (Path G > G06 > G06V > G06V40/00 > G06V40/60)
# 분류: 1
# 내용: PHYSICS COMPUTING CALCULATING OR COUNTING IMAGE OR VIDEO RECOGNITION OR UNDERSTANDING Recognition of biometric, human-related or animal-related patterns in image or video data Static or dynamic means for assisting the user to position a body part for biometric acquisition
# --- [Rank 3] (거리: 1.0851) ---
# 코드: A61B3/09 (Path A > A61 > A61B > A61B3/00 > A61B3/02 > A61B3/09)
# 분류: 2
# 내용: HUMAN NECESSITIES MEDICAL OR VETERINARY SCIENCE HYGIENE DIAGNOSIS SURGERY IDENTIFICATION Apparatus for testing the eyes Instruments for examining the eyes Subjective types, i.e. testing apparatus requiring the active assistance of the patient for testing accommodation
# --- [Rank 4] (거리: 1.1050) ---
# 코드: G06V40/50 (Path G > G06 > G06V > G06V40/00 > G06V40/50)
# 분류: 1
# 내용: PHYSICS COMPUTING CALCULATING OR COUNTING IMAGE OR VIDEO RECOGNITION OR UNDERSTANDING Recognition of biometric, human-related or animal-related patterns in image or video data Maintenance of biometric data or enrolment thereof
# --- [Rank 5] (거리: 1.1073) ---
# 코드: A61B3/03 (Path A > A61 > A61B > A61B3/00 > A61B3/02 > A61B3/02 > A61B3/03)
# 분류: 3
# 내용: HUMAN NECESSITIES MEDICAL OR VETERINARY SCIENCE HYGIENE DIAGNOSIS SURGERY IDENTIFICATION Apparatus for testing the eyes Instruments for examining the eyes Subjective types, i.e. testing apparatus requiring the active assistance of the patient Subjective types, i.e. testing apparatus requiring the active assistance of the patient Devices for presenting test symbols or characters, e.g. test chart projectors
# --- [Rank 6] (거리: 1.1079) ---
# 코드: A61B34/20 (Path A > A61 > A61B > A61B34/00 > A61B34/20)
# 분류: 1
# 내용: HUMAN NECESSITIES MEDICAL OR VETERINARY SCIENCE HYGIENE DIAGNOSIS SURGERY IDENTIFICATION Computer-aided surgery Manipulators or robots specially adapted for use in surgery Surgical navigation systems Devices for tracking or guiding surgical instruments, e.g. for frameless stereotaxis
# --- [Rank 7] (거리: 1.1111) ---
# 코드: A61B3/06 (Path A > A61 > A61B > A61B3/00 > A61B3/02 > A61B3/06)
# 분류: 2
# 내용: HUMAN NECESSITIES MEDICAL OR VETERINARY SCIENCE HYGIENE DIAGNOSIS SURGERY IDENTIFICATION Apparatus for testing the eyes Instruments for examining the eyes Subjective types, i.e. testing apparatus requiring the active assistance of the patient for testing light sensitivity, e.g. adaptation for testing colour vision
# --- [Rank 8] (거리: 1.1153) ---
# 코드: A61B3/02 (Path A > A61 > A61B > A61B3/00 > A61B3/02)
# 분류: 1
# 내용: HUMAN NECESSITIES MEDICAL OR VETERINARY SCIENCE HYGIENE DIAGNOSIS SURGERY IDENTIFICATION Apparatus for testing the eyes Instruments for examining the eyes Subjective types, i.e. testing apparatus requiring the active assistance of the patient
# --- [Rank 9] (거리: 1.1159) ---
# 코드: A61B3/04 (Path A > A61 > A61B > A61B3/00 > A61B3/02 > A61B3/02 > A61B3/04)
# 분류: 3
# 내용: HUMAN NECESSITIES MEDICAL OR VETERINARY SCIENCE HYGIENE DIAGNOSIS SURGERY IDENTIFICATION Apparatus for testing the eyes Instruments for examining the eyes Subjective types, i.e. testing apparatus requiring the active assistance of the patient Subjective types, i.e. testing apparatus requiring the active assistance of the patient Trial frames Sets of lenses for use therewith
# --- [Rank 10] (거리: 1.1202) ---
# 코드: A61B3/15 (Path A > A61 > A61B > A61B3/00 > A61B3/10 > A61B3/14 > A61B3/15)
# 분류: 3
# 내용: HUMAN NECESSITIES MEDICAL OR VETERINARY SCIENCE HYGIENE DIAGNOSIS SURGERY IDENTIFICATION Apparatus for testing the eyes Instruments for examining the eyes Objective types, i.e. instruments for examining the eyes independent of the patients perceptions or reactions Arrangements specially adapted for eye photography with means for aligning, spacing or blocking spurious reflection

# %%
# ID(IPC코드) 리스트로 데이터 한방에 가져오기
target_codes = ["A61B 5/00", "G06V 10/00"]

results = ipc_collection.get(ids=target_codes)

print(results["documents"])  # 해당 코드들의 설명 텍스트 출력
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # ID(IPC코드) 리스트로 데이터 한방에 가져오기
#       2 target_codes = ["A61B 5/00", "G06V 10/00"]
# ----> 4 results = ipc_collection.get(
#       5     ids=target_codes
#       6 )
#       8 print(results['documents']) # 해당 코드들의 설명 텍스트 출력
#
# NameError: name 'ipc_collection' is not defined
