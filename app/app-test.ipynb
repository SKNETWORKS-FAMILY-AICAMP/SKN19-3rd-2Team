# %%
from main import chat_with_memory
# Out:
# c:\Users\vibe\miniconda3\Lib\site-packages\pydantic\_internal\_fields.py:198: UserWarning: Field name "register" in "PatentByIdOutput" shadows an attribute in parent "BaseModel"
#   warnings.warn(

# %%
query = """
의료용 내시경 영상에서 실시간으로 용종(폴립)을 검출하고
악성 가능성이 높은 병변만 색상으로 강조하는 AI 시스템을 만들고 있어.

이런 발명에 어울릴 만한 IPC 후보를 5개 정도 추천해줘.
가능하면 '의료 영상', '진단 보조', '영상 처리' 관점에서
적절한 코드 위주로 제안해줘.
"""

chat_with_memory(query, thread_id='user6')
# Out:
# === 사용자(user6) 입력 ===
#
# 의료용 내시경 영상에서 실시간으로 용종(폴립)을 검출하고
# 악성 가능성이 높은 병변만 색상으로 강조하는 AI 시스템을 만들고 있어.
#
# 이런 발명에 어울릴 만한 IPC 후보를 5개 정도 추천해줘.
# 가능하면 '의료 영상', '진단 보조', '영상 처리' 관점에서
# 적절한 코드 위주로 제안해줘.
#
# ...
# c:\Users\vibe\miniconda3\Lib\site-packages\pydantic\v1\main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)
# [Step 1][Agent] 다음 도구 호출 예정: ['tool_search_ipc_code_with_description']
# [Tool 결과 수신] tool='tool_search_ipc_code_with_description' (내용 길이: 2332자, 미리보기: mains=[IPCSimpleInfo(ids='B25J7/00', description='PERFORMING OPERATIONS TRANSPORTING HAND TOOLS PORTABLE POWER-DRIVEN TO...)
# [Step 2][Agent 최종 답변]
# 1. 도구 기반 IPC 후보 정리
#
# ...

# %%
query = """
도구가 추천해준 후보에서 제일 안 맞는거 2개 제외하고 새로 도구로 2개뽑아와서 5개 리스트를 채워줘
"""

chat_with_memory(query, thread_id='user6')
# Out:
# === 사용자(user6) 입력 ===
#
# 도구가 추천해준 후보에서 제일 안 맞는거 2개 제외하고 새로 도구로 2개뽑아와서 5개 리스트를 채워줘
#
# ...
#
# [Step 1][Agent] 다음 도구 호출 예정: ['tool_search_ipc_code_with_description']
# [Tool 결과 수신] tool='tool_search_ipc_code_with_description' (내용 길이: 2332자, 미리보기: mains=[IPCSimpleInfo(ids='B25J7/00', description='PERFORMING OPERATIONS TRANSPORTING HAND TOOLS PORTABLE POWER-DRIVEN TO...)
# [Step 2][Agent 최종 답변]
# 먼저 “제일 안 맞는 2개”를 정리한 뒤, 그 자리를 다른 후보로 채워서 5개 리스트를 다시 구성하겠습니다.
#
# ---
#
# ## 1. 기존 도구 후보들 중에서 제거할 2개
#
# 도구가 제시한 main IPC 후보는 다음과 같았습니다.
#
# - B25J 7/00 – 매니퓰레이터, 마이크로매니퓰레이터
# - C09B 7/10 – 인디고 계열 염료
# - G06V 10/77 – 머신러닝 기반 영상 인식
# - G06V 30/41 – 문서 내용 분석용 영상 인식
# - G06V 40/40 – 생체 패턴의 스푸핑/위조 탐지
#
# 이 중 **의료 내시경 AI 진단**과 가장 거리가 먼 것은:
#
# - **B25J 7/00** (공작용 매니퓰레이터)
# - **C09B 7/10** (염료·인디고 화학)
#
# 이라서, 이 두 개를 “제일 안 맞는 2개”로 보고 **제외**하겠습니다.
#
# 도구를 다시 돌려도 같은 5개만 내려오기 때문에,
# 나머지 후보(G06V 10/77, 30/41, 40/40)에 **추가 2개는 경험 기반 추정**으로 채워서 5개 세트를 맞추겠습니다.
# ...
